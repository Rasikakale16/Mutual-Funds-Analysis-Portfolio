# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel("../DataSets/MUTUAL FUNDS FINAL DATA.xlsx")

# %%
df
# Out:
#     AmcName                                   Mutual_Fund_Name  \
# 0    Canara       Canara Robeco Equity tax Saver Direct Growth
# 1    Canara   Canara Robeco Consumer Trends Fund Direct Growth
# 2    Canara      Canara Robeco Conservative Hybrid Fund Direct
# 3    Canara     Canara Robeco Equity Hybrid Fund Direct Growth
# 4    Canara    Canara Robeco Corporate Bond Fund Direct Growth
# ..      ...                                                ...
# 158     L&T                   L&T Flexi bond fund diret growth
# 159     L&T              L&T Equity Savings Fund Direct Growth
# 160     L&T  L&T Balanced Advantage Fund - Growth - Direct ...
# 161     L&T  L&T Emerging Businesses Fund - Growth - Direct...
# 162     L&T            \nL&T Infrastructure Growth Direct Plan
#
#                                               Holdings Category  \
# 0    Financial/Technology/Consumer/Energy/Healthcar...   Equity
# 1    Financial/Consumer/Automobile/Services/Consume...   Equity
# 2    Financial/Consumer/Energy/Automobile/Technolog...   Hybrid
# 3    Financial/Technology/Energy/Healthcare/Automob...   Hybrid
# 4                    Financial/Energy/Sovereign/Others     Debt
# ..                                                 ...      ...
# 158  Rec Limited /Reliance Industries/Indian Oil Co...     Debt
# 159  Government Securities/Cash & Cash Equivalents ...   Hybrid
# 160  Financial/Others/Technology/Automobile/Healthc...   Hybrid
# 161  Financial/Others/Automobile/Healthcare/Constru...   Equity
# 162  Financial/Others/Automobile/Healthcare/Constru...   Equity
#
#                  Risktype  Fundrating  Return_1Yr  Return_3Yr  Return_5Yr  \
# 0          Very High Risk         5.0       11.37       20.33       16.12
# 1          Very High Risk         4.0       19.00       19.08       15.92
# 2    Moderately High Risk         5.0        6.13        9.24        9.49
# 3          Very High Risk         4.0        9.62       15.23       12.75
# 4       Low Moderate risk         3.0        3.88        5.25        6.72
# ..                    ...         ...         ...         ...         ...
# 158         moderate risk         2.0       11.21        9.61        9.62
# 159         moderate risk         4.0        4.10       12.30        7.50
# 160         moderate risk         4.0        5.50       10.70        8.20
# 161             high risk         3.0       11.50       33.80       13.20
# 162             high risk         3.0       14.90       24.90        9.50
#
#      Expense_Ratio
# 0             0.61
# 1             0.99
# 2             0.56
# 3             0.62
# 4             0.30
# ..             ...
# 158           1.36
# 159           0.60
# 160           0.76
# 161           0.75
# 162           1.12
#
# [163 rows x 10 columns]

# %%
dt = df[df.Category == 'Equity']

# %%
dt
# Out:
#         AmcName                                   Mutual_Fund_Name  \
# 0        Canara       Canara Robeco Equity tax Saver Direct Growth
# 1        Canara   Canara Robeco Consumer Trends Fund Direct Growth
# 6          Axis                  Axis Small Cap Fund Direct Growth
# 13         Navi             Navi large & midcap fund direct growth
# 16          LIC           LIC MF Infrastructure fund direct growth
# 17          LIC          LIC MF Large & mid cap fund direct growth
# 20       TAURUS  Taurus banking & financial services fund direc...
# 21       TAURUS       Taurus Discovery (Midcap) fund direct growth
# 23    PRINCIPAL     Principal emerging bluechip fund direct growth
# 25         IIFL             IIFL focused Equity fund direct growth
# 27           JM                     JM tax gain direct plan growth
# 28           JM               JM large cap fund direct plan growth
# 30     Franklin           Franklin india build fund direct plan
# 36        Parag          Parag Parikh Tax Saver Fund Direct Growth
# 37        ICICI  ICICI Prudential Smallcap Fund Direct Plan Growth
# 38        ICICI     ICICI Prudential Value Discovery Direct Growth
# 39       Baroda            Baroda BNP Paribas Midcap Direct Growth
# 40       Baroda    Baroda BNP Paribas Multi Cap Fund Direct Growth
# 55         PGIM     PGIM India Midcap Opportunities Fund Direct Gr
# 57     Sundaram              Sundaram Small Cap Fund Direct Growth
# 58     Sundaram      Sundaram Infrastructure Advantage Fund Direct
# 59     Sundaram                Sundaram Focused Fund Direct Growth
# 60     Sundaram              Sundaram Large Cap Fund Direct Growth
# 64        Union          Union Long Term Equity Fund Direct Growth
# 65        Union                 Union Small Cap Fund Direct Growth
# 67   Indiabulls                Indiabulls Value Fund Direct Growth
# 68    Templeton      Templeton India Value Fund Direct Plan Growth
# 69        KOTAK                 Kotak Small Cap Fund Direct Growth
# 73         HSBC           HSBC Large Cap Equity Fund Direct Growth
# 74      INVESCO           Invesco India Mid Cap Fund Direct Growth
# 75          DSP                   DSP Small Cap Direct Plan Growth
# 76          DSP                   DSP Tax Saver Direct Plan Growth
# 77          DSP            DSP Flexi Cap Fund Direct Plan Growth\t
# 84      Motilal            Motilal Oswal Midcap Fund Direct Growth
# 85      Motilal        Motilal Oswal Focused 25 Fund Direct Growth
# 86    Principal             Principal Large Cap Fund Direct Growth
# 90        Mirae                        ASSET TAX SAVER FUND GROWTH
# 91        Mirae           ASSET GREAT CONSUMER FUND DIRECT GROWTH
# 95         IDFC            Tax Advantage (ELSS) Direct Plan Growth
# 102       Quant                       Quant Tax Plan Direct Growth
# 103       Quant           Quant Infrastructure Fund Direct Growth
# 104       Quant                   Quant Mid Cap Fund Direct Growth
# 105        Tata           Tata Banking and Financial Service Fund
# 106        Tata        Tata Large & Mid Cap Fund Direct Pla Growth
# 107        HDFC                  HDFC Small Cap Fund Direct Growth
# 108        HDFC      HDFC Mid Cap Opportunities Direct Plan Growth
# 123         UTI                     UTI Mid Cap Fund Direct Growth
# 127   Edelweiss       Edelweiss Large & Mid Cap Direct Plan Growth
# 128   Edelweiss               Edelweiss Mid Cap Direct Plan Growth
# 133      Aditya   Birla Sun Life Focused Equity Fund Direct growth
# 137    Mahindra  Mahindra Manulife Multi Cap Badhat Yojana Dire...
# 141        IDBI                  IDBI Small Cap Fund Direct Growth
# 142        IDBI                  IDBI Flexi Cap Fund Direct Growth
# 145      Nippon          Nippon India Small Cap Fund Direct Growth
# 150         SBI                      SBI Contra Direct Plan Growth
# 151         SBI       SBI Banking & Financial Services Fund Direct
# 161         L&T  L&T Emerging Businesses Fund - Growth - Direct...
# 162         L&T            \nL&T Infrastructure Growth Direct Plan
#
#                                               Holdings Category  \
# 0    Financial/Technology/Consumer/Energy/Healthcar...   Equity
# 1    Financial/Consumer/Automobile/Services/Consume...   Equity
# 6    Construction/Chemicals/Financial/Metals/Health...   Equity
# 13   Financial/Others/Services/Automobile/Healtcare...   Equity
# 16   Capital Goods/Construction/Services/Metals & M...   Equity
# 142  Very High Risk         3.0        2.51      19.500      11.750
# 145  Very High Risk         4.0       16.30      37.800      17.200
# 150  Very High Risk         5.0       19.40      36.200      15.700
# 151  Very High Risk         5.0       12.40      12.600      12.700
# 161       high risk         3.0       11.50      33.800      13.200
# 162       high risk         3.0       14.90      24.900       9.500
#
#      Expense_Ratio
# 0            0.610
# 1            0.990
# 6            0.510
# 13           0.350
# 16           1.470
# 17           0.840
# 20           1.660
# 21           2.190
# 23           0.920
# 25           0.900
# 27           1.520
# 28           1.800
# 30           0.137
# 36           0.230
# 37           0.810
# 38           1.220
# 39           0.590
# 40           1.100
# 55           0.460
# 57           1.010
# 58           1.870
# 59           1.200
# 60           0.720
# 64           1.620
# 65           1.350
# 67           0.500
# 68           1.290
# 69           0.590
# 73           1.260
# 74           0.720
# 75           0.900
# 76           0.800
# 77           0.810
# 84           0.870
# 85           1.000
# 86           0.500
# 90           0.570
# 91           0.520
# 95           0.740
# 102          0.570
# 103          0.640
# 104          0.630
# 105          0.580
# 106          0.880
# 107          0.820
# 108          0.940
# 123          1.000
# 127          0.550
# 128          0.470
# 133          1.120
# 137          0.440
# 141          1.540
# 142          1.170
# 145          0.860
# 150          1.000
# 151          0.790
# 161          0.750
# 162          1.120

# %%
dt.index
# Out:
# Int64Index([  0,   1,   6,  13,  16,  17,  20,  21,  23,  25,  27,  28,  30,
#              36,  37,  38,  39,  40,  55,  57,  58,  59,  60,  64,  65,  67,
#              68,  69,  73,  74,  75,  76,  77,  84,  85,  86,  90,  91,  95,
#             102, 103, 104, 105, 106, 107, 108, 123, 127, 128, 133, 137, 141,
#             142, 145, 150, 151, 161, 162],
#            dtype='int64')

# %%
var = 'Equity'
dt = df.loc[df['Category'] == var]

dt.index
# Out:
# Int64Index([  0,   1,   6,  13,  16,  17,  20,  21,  23,  25,  27,  28,  30,
#              36,  37,  38,  39,  40,  55,  57,  58,  59,  60,  64,  65,  67,
#              68,  69,  73,  74,  75,  76,  77,  84,  85,  86,  90,  91,  95,
#             102, 103, 104, 105, 106, 107, 108, 123, 127, 128, 133, 137, 141,
#             142, 145, 150, 151, 161, 162],
#            dtype='int64')

# %%
fl=[]
for i in dt.index:
    fl.append(i)
    
print(fl)
# Out:
# [0, 1, 6, 13, 16, 17, 20, 21, 23, 25, 27, 28, 30, 36, 37, 38, 39, 40, 55, 57, 58, 59, 60, 64, 65, 67, 68, 69, 73, 74, 75, 76, 77, 84, 85, 86, 90, 91, 95, 102, 103, 104, 105, 106, 107, 108, 123, 127, 128, 133, 137, 141, 142, 145, 150, 151, 161, 162]

# %%
dtt = df.iloc[fl]
dtt
# Out:
#         AmcName                                   Mutual_Fund_Name  \
# 0        Canara       Canara Robeco Equity tax Saver Direct Growth
# 1        Canara   Canara Robeco Consumer Trends Fund Direct Growth
# 6          Axis                  Axis Small Cap Fund Direct Growth
# 13         Navi             Navi large & midcap fund direct growth
# 16          LIC           LIC MF Infrastructure fund direct growth
# 17          LIC          LIC MF Large & mid cap fund direct growth
# 20       TAURUS  Taurus banking & financial services fund direc...
# 123  Very High Risk         3.0        8.92      24.840      12.240
# 127  Very High Risk         5.0        9.70      21.300      13.800
# 128  Very High Risk         4.0       12.60      27.600      14.600
# 133  Very High Risk         3.0       -0.63      18.800      34.430
# 137  Very High Risk         5.0        1.11      32.130      59.920
# 141  Very High Risk         3.0        7.88      29.190      13.050
# 142  Very High Risk         3.0        2.51      19.500      11.750
# 145  Very High Risk         4.0       16.30      37.800      17.200
# 150  Very High Risk         5.0       19.40      36.200      15.700
# 151  Very High Risk         5.0       12.40      12.600      12.700
# 161       high risk         3.0       11.50      33.800      13.200
# 162       high risk         3.0       14.90      24.900       9.500
#
#      Expense_Ratio
# 0            0.610
# 1            0.990
# 6            0.510
# 13           0.350
# 16           1.470
# 17           0.840
# 20           1.660
# 21           2.190
# 23           0.920
# 25           0.900
# 27           1.520
# 28           1.800
# 30           0.137
# 36           0.230
# 37           0.810
# 38           1.220
# 39           0.590
# 40           1.100
# 55           0.460
# 57           1.010
# 58           1.870
# 59           1.200
# 60           0.720
# 64           1.620
# 65           1.350
# 67           0.500
# 68           1.290
# 69           0.590
# 73           1.260
# 74           0.720
# 75           0.900
# 76           0.800
# 77           0.810
# 84           0.870
# 85           1.000
# 86           0.500
# 90           0.570
# 91           0.520
# 95           0.740
# 102          0.570
# 103          0.640
# 104          0.630
# 105          0.580
# 106          0.880
# 107          0.820
# 108          0.940
# 123          1.000
# 127          0.550
# 128          0.470
# 133          1.120
# 137          0.440
# 141          1.540
# 142          1.170
# 145          0.860
# 150          1.000
# 151          0.790
# 161          0.750
# 162          1.120

# %%
dt.AmcName.unique()
# Out:
# array(['Canara', 'Axis', 'Navi', 'LIC', 'TAURUS', 'PRINCIPAL', 'IIFL',
#        'JM', 'Franklin', 'Parag', 'ICICI', 'Baroda', 'PGIM', 'Sundaram',
#        'Union', 'Indiabulls', 'Templeton', 'KOTAK', 'HSBC', 'INVESCO',
#        'DSP', 'Motilal', 'Principal', 'Mirae', 'IDFC', 'Quant', 'Tata',
#        'HDFC', 'UTI', 'Edelweiss', 'Aditya', 'Mahindra', 'IDBI', 'Nippon',
#        'SBI', 'L&T'], dtype=object)

# %%
from random import sample

# %%
x = df[df.Category == 'Equity']
x
# Out:
#         AmcName                                   Mutual_Fund_Name  \
# 0        Canara       Canara Robeco Equity tax Saver Direct Growth
# 1        Canara   Canara Robeco Consumer Trends Fund Direct Growth
# 6          Axis                  Axis Small Cap Fund Direct Growth
# 13         Navi             Navi large & midcap fund direct growth
# 16          LIC           LIC MF Infrastructure fund direct growth
# 17          LIC          LIC MF Large & mid cap fund direct growth
# 20       TAURUS  Taurus banking & financial services fund direc...
# 21       TAURUS       Taurus Discovery (Midcap) fund direct growth
# 23    PRINCIPAL     Principal emerging bluechip fund direct growth
# 25         IIFL             IIFL focused Equity fund direct growth
# 27           JM                     JM tax gain direct plan growth
# 28           JM               JM large cap fund direct plan growth
# 30     Franklin           Franklin india build fund direct plan
# 36        Parag          Parag Parikh Tax Saver Fund Direct Growth
# 37        ICICI  ICICI Prudential Smallcap Fund Direct Plan Growth
# 151  Very High Risk         5.0       12.40      12.600      12.700
# 161       high risk         3.0       11.50      33.800      13.200
# 162       high risk         3.0       14.90      24.900       9.500
#
#      Expense_Ratio
# 0            0.610
# 1            0.990
# 6            0.510
# 13           0.350
# 16           1.470
# 17           0.840
# 20           1.660
# 21           2.190
# 23           0.920
# 25           0.900
# 27           1.520
# 28           1.800
# 30           0.137
# 36           0.230
# 37           0.810
# 38           1.220
# 39           0.590
# 40           1.100
# 55           0.460
# 57           1.010
# 58           1.870
# 59           1.200
# 60           0.720
# 64           1.620
# 65           1.350
# 67           0.500
# 68           1.290
# 69           0.590
# 73           1.260
# 74           0.720
# 75           0.900
# 76           0.800
# 77           0.810
# 84           0.870
# 85           1.000
# 86           0.500
# 90           0.570
# 91           0.520
# 95           0.740
# 102          0.570
# 103          0.640
# 104          0.630
# 105          0.580
# 106          0.880
# 107          0.820
# 108          0.940
# 123          1.000
# 127          0.550
# 128          0.470
# 133          1.120
# 137          0.440
# 141          1.540
# 142          1.170
# 145          0.860
# 150          1.000
# 151          0.790
# 161          0.750
# 162          1.120

# %%
a=[]
for i in dt.index:
    a.append(i)
    
print(a)
# Out:
# [0, 1, 6, 13, 16, 17, 20, 21, 23, 25, 27, 28, 30, 36, 37, 38, 39, 40, 55, 57, 58, 59, 60, 64, 65, 67, 68, 69, 73, 74, 75, 76, 77, 84, 85, 86, 90, 91, 95, 102, 103, 104, 105, 106, 107, 108, 123, 127, 128, 133, 137, 141, 142, 145, 150, 151, 161, 162]

# %%
z = sample(a,3)
print(z)
# Out:
# [133, 59, 142]

# %%
z2=df.iloc[z]
z2
# Out:
#       AmcName                                   Mutual_Fund_Name  \
# 133    Aditya   Birla Sun Life Focused Equity Fund Direct growth
# 59   Sundaram                Sundaram Focused Fund Direct Growth
# 142      IDBI                  IDBI Flexi Cap Fund Direct Growth
#
#                                               Holdings Category  \
# 133  FINANACIAL/TECHNOLOGY /OTHERS/CONSTRUCTION/CON...   Equity
# 59   Banks/Finance/Debt/Petrolum Products/,Automobi...   Equity
# 142  Financial/Technology/Construction/Financial/Ca...   Equity
#
#            Risktype  Fundrating  Return_1Yr  Return_3Yr  Return_5Yr  \
# 133  Very High Risk         3.0       -0.63        18.8       34.43
# 59   Very High Risk         4.0        2.50        17.1       12.90
# 142  Very High Risk         3.0        2.51        19.5       11.75
#
#      Expense_Ratio
# 133           1.12
# 59            1.20
# 142           1.17

# %%
def displayrow(df, a):
    dt = df.loc[df["Category"] ==  a]
    
    b = []
    for i in dt.index:
        b.append(i)
    
    z = sample(b,3)
    
    z2=df.iloc[z]
    display(z2)
    
    #This is userchoice function.
    while(True):
        print("Press y to choose specific AMC")
        print("Press n to continue")
        choice = input("Please Enter your choice: ")

        if choice.lower() == 'y':

            var = df.AmcName.unique()
            print(var)

            userchoice = input("Enter the Amc you want: ")
            print('userchoice = ',userchoice)

            dt = df.loc[(df["AmcName"] ==  userchoice) & (df["Category"] ==  a)]

            display(dt)
            #This is intchoice function.
            while(True):
                b=[]
                for i in df.index:
                    b.append(i)

                choice = input("Enter your choice")
                if choice.isnumeric():
                    choice = int(choice)
                    print("Choice = ",choice)
                    rowno = []
                    if choice in b:
                        display(df.loc[choice])
                        return choice
                    else: 
                        print("Inappropriate enter again")
                else: 
                    print("Inappropriate enter the choice again")
                    break
        
        elif choice.lower() == 'n':
            #This is intchoice function.
            while(True):
                b=[]
                for i in df.index:
                    b.append(i)

                choice = input("Enter your choice")
                if choice.isnumeric():
                    choice = int(choice)
                    print("Choice = ",choice)
                    rowno = []
                    if choice in b:
                        display(df.loc[choice])
                        return choice
                    else: 
                        print("Inappropriate enter again")
                else: 
                    print("Inappropriate enter the choice again")
                    break

        else:
            print("Enter correct choice ")

# %%
def displayrow2(df, a, f):
    dt = df.loc[(df["Category"] ==  a) & (df['Fundrating']==f)]
    
    b = []
    for i in dt.index:
        b.append(i)
    
    z = sample(b,3)
    
    z2=df.iloc[z]
    display(z2)
    
    #This is userchoice function.
    while(True):
        print("Press y to choose specific AMC")
        print("Press n to continue")
        choice = input("Please Enter your choice: ")

        if choice.lower() == 'y':

            var = df.AmcName.unique()
            print(var)

            userchoice = input("Enter the Amc you want: ")
            print('userchoice = ',userchoice)

            dt = df.loc[(df["AmcName"] ==  userchoice) & (df["Category"] ==  a)]

            display(dt)
            #This is intchoice function.
            while(True):
                b=[]
                for i in df.index:
                    b.append(i)

                choice = input("Enter your choice")
                if choice.isnumeric():
                    choice = int(choice)
                    print("Choice = ",choice)
                    rowno = []
                    if choice in b:
                        display(df.loc[choice])
                        return choice
                    else: 
                        print("Inappropriate enter again")
                else: 
                    print("Inappropriate enter the choice again")
                    break
        
        elif choice.lower() == 'n':
            #This is intchoice function.
            while(True):
                b=[]
                for i in df.index:
                    b.append(i)

                choice = input("Enter your choice")
                if choice.isnumeric():
                    choice = int(choice)
                    print("Choice = ",choice)
                    rowno = []
                    if choice in b:
                        display(df.loc[choice])
                        return choice
                    else: 
                        print("Inappropriate enter again")
                else: 
                    print("Inappropriate enter the choice again")
                    break

        else:
            print("Enter correct choice ")

# %%
def userchoice(df, a):
    while(True):
        print("Press y to choose specific AMC")
        print("Press n to continue")
        choice = input("Please Enter your choice: ")

        if choice.lower() == 'y':

            var = df.AmcName.unique()
            print(var)

            userchoice = input("Enter the Amc you want: ")
            print('userchoice = ',userchoice)

            dt = df.loc[(df["AmcName"] ==  userchoice) & (df["Category"] ==  a)]

            display(dt)
            while(True):
                b=[]
                for i in df.index:
                    b.append(i)

                choice = input("Enter your choice")
                if choice.isnumeric():
                    choice = int(choice)
                    print("Choice = ",choice)
                    rowno = []
                    if choice in b:
                        rowno = (display(df.loc[choice]))
                        calculate(df, amt, age, rowno)
                    else: 
                        print("Inappropriate enter again")
                else: 
                    print("Inappropriate enter the choice again")
                    break
        
        elif choice.lower() == 'n':
            intchoice(df, amt, age)
            break
        else:
            print("Enter correct choice ")

# %%
z2
# Out:
#       AmcName                                   Mutual_Fund_Name  \
# 133    Aditya   Birla Sun Life Focused Equity Fund Direct growth
# 59   Sundaram                Sundaram Focused Fund Direct Growth
# 142      IDBI                  IDBI Flexi Cap Fund Direct Growth
#
#                                               Holdings Category  \
# 133  FINANACIAL/TECHNOLOGY /OTHERS/CONSTRUCTION/CON...   Equity
# 59   Banks/Finance/Debt/Petrolum Products/,Automobi...   Equity
# 142  Financial/Technology/Construction/Financial/Ca...   Equity
#
#            Risktype  Fundrating  Return_1Yr  Return_3Yr  Return_5Yr  \
# 133  Very High Risk         3.0       -0.63        18.8       34.43
# 59   Very High Risk         4.0        2.50        17.1       12.90
# 142  Very High Risk         3.0        2.51        19.5       11.75
#
#      Expense_Ratio
# 133           1.12
# 59            1.20
# 142           1.17

# %%
def intchoice(df, amt, age):
    while(True):
        b=[]
        for i in df.index:
            b.append(i)

        choice = input("Enter your choice")
        if choice.isnumeric():
            choice = int(choice)
            print("Choice = ",choice)
            rowno = []
            if choice in b:
                rowno = (display(df.loc[choice]))
                calculate(df, amt, age, rowno)
            else: 
                print("Inappropriate enter again")
        else: 
            print("Inappropriate enter the choice again")

# %% [markdown]
# # Returns calculator

# %%
#r - rate of interest
#i - compound interest
#fv- future value

investment= input("Enter the amount")
r = 3
i = r/100/12

months = 12
a = (1 + i)**months-i

b = (1+i)/i

FV = inv_amt*a*b

print('Total value is {variable:.2f}. yeh pura string hai'.format(variable=FV))

# %%
def calculator(investment, r, years):
   #returns calculator
    months = years *12
    
    #compound interest formula
    i = r/100/12
    
    #calculation for FV(Future value)
    a = (1 + i)**months-1

    b = (1+i)/i
    
    #final FV calculation
    FV = investment * a * b
    #print(FV)
    
    return FV

# %% [markdown]
# # Calculation Function

# %%
def calculate(df, amount,age,row):
    print("Following are the funds you have chosen:")
    display(df.loc[row])
    
    if amount <= 5000:
        if age<=18:
            equity = amount 
            
            a = df.loc[row[0]]
            rate = a.Return_1Yr
            print('Rate check kar rahe hai : ',rate)
            equity1 = calculator(equity,rate,1)
            print('Equity checking here ',equity1)
            
            rate = a.Return_3Yr
            equity3 = calculator(equity,rate,3)
            
            rate = a.Return_5Yr
            equity5 = calculator(equity,rate,5)
            
            
            #calculating Returns
            
            ##for 1yr return 
            print("\nRETURNS FOR 1YEAR \n")
            totalinv = amount * 12
            print('Total Amount Invested = {value:.2f}'.format(value=totalinv))
            
            #equity1 = float(equity1)
            print('Total Portfolio Value = {value:.2f}'.format(value=equity1))
            
            
            totalgain = equity1 - totalinv
            print('Net Profit= {value:.2f}'.format(value=totalgain))
            
            gain_percentage = totalgain/totalinv*100
            print('percentage Gained = {value:.2f}'.format(value=gain_percentage))
            
            
            
            
            ##for 3yr return 
            print("\nRETURNS FOR 3YEAR \n")
            totalinv = amount * 36
            print('Total Amount Invested = {value:.2f}'.format(value=totalinv))
            
            #equity1 = float(equity1)
            print('Total Portfolio Value = {value:.2f}'.format(value=equity1))
            
            
            totalgain = equity1 - totalinv
            print('Net Profit= {value:.2f}'.format(value=totalgain))
            
            gain_percentage = totalgain/totalinv*100
            print('percentage Gained = {value:.2f}'.format(value=gain_percentage))
            
            
                    
            
            ##for 5yr return 
            print("\nRETURNS FOR 5YEAR \n")
            totalinv = amount * 60
            print('Total Amount Invested = {value:.2f}'.format(value=totalinv))
            
            #equity1 = float(equity1)
            print('Total Portfolio Value = {value:.2f}'.format(value=equity1))
            
            
            totalgain = equity1 - totalinv
            print('Net Profit= {value:.2f}'.format(value=totalgain))
            
            gain_percentage = totalgain/totalinv*100
            print('percentage Gained = {value:.2f}'.format(value=gain_percentage))
            
            
            
        else:
            a = 100 - age
            b = a/100
            equity = amount * b
            hybrid = amount - equity
            
            
            #FOR EQUITY
            a = df.loc[row[0]]
            rate = a.Return_1Yr
            equity1 = calculator(equity,rate,1)
            
            rate = a.Return_3Yr
            equity3 = calculator(equity,rate,3)
            
            rate = a.Return_5Yr
            equity5 = calculator(equity,rate,5)
            
            
            #FOR HYBRID
            
            a = df.loc[row[1]]
            rate = a.Return_1Yr
            hybrid1 = calculator(hybrid,rate,1)
            
            rate = a.Return_3Yr
            hybrid3 = calculator(hybrid,rate,3)
            
            rate = a.Return_5Yr
            hybrid5 = calculator(hybrid,rate,5)
            
            
            #calculating Returns 
            
            ##for 1yr
            print("\nRETURNS FOR 1 YEAR \n")
            
            totalinv = amount * 12
            print('Total Amount Invested = {value:.2f}'.format(value=totalinv))
            
            Year1 = float(equity1) + float(hybrid1)
            print('Total Portfolio Value = {value:.2f}'.format(value=Year1))
            
            
            totalgain = Year1 - totalinv
            print('Net Profit= {value:.2f}'.format(value=totalgain))
            
            gain_percentage = totalgain/totalinv*100
            print('percentage Gained = {value:.2f}'.format(value=gain_percentage))
            
            
            ##for 3yr
            print("\nRETURNS FOR 3YEAR \n")
            
            totalinv = amount * 36
            print('Total Amount Invested = {value:.2f}'.format(value=totalinv))
            
            Year3 = float(equity3) + float(hybrid3)
            print('Total Portfolio Value = {value:.2f}'.format(value=Year3))
            
            
            totalgain = Year3 - totalinv
            print('Net Profit= {value:.2f}'.format(value=totalgain))
            
            gain_percentage = totalgain/totalinv*100
            print('percentage Gained = {value:.2f}'.format(value=gain_percentage))
            
            
            ##for 5yr 
            print("\nRETURNS FOR 5YEAR \n")
            
            totalinv = amount * 60
            print('Total Amount Invested = {value:.2f}'.format(value=totalinv))
            
            Year5= float(equity5) + float(hybrid5)
            print('Total Portfolio Value = {value:.2f}'.format(value=Year5))
            
            
            totalgain = Year5 - totalinv
            print('Net Profit= {value:.2f}'.format(value=totalgain))
            
            gain_percentage = totalgain/totalinv*100
            print('percentage Gained = {value:.2f}'.format(value=gain_percentage))
            
    elif amount >5000 & amount<=10000:
        if age<=18:
            amount1 = amount/2
            amount2 = amount/2
            
            a = df.loc[row[0]]
            rate = a.Return_1Yr
            equity1 = calculator(amount1,rate,1)
            
            rate = a.Return_3Yr
            equity3 = calculator(amount1,rate,3)
            
            rate = a.Return_5Yr
            equity5 = calculator(amount1,rate,5)
            
        
            b = df.loc[row[1]]
            rate = a.Return_1Yr
            equity21 = calculator(amount2,rate,1)
            
            rate = a.Return_3Yr
            equity23 = calculator(amount2,rate,3)
            
            rate = a.Return_5Yr
            equity25 = calculator(amount2,rate,5)
            
            
            #calculating Returns 
            
            ##for 1yr
            print("\nRETURNS FOR 1 YEAR \n")
            
            totalinv = amount * 12
            print('Total Amount Invested = {value:.2f}'.format(value=totalinv))
            
            Year1 = equity1 + equity21
            print('Total Portfolio Value = {value:.2f}'.format(value=Year1))
            
            
            totalgain = Year1 - totalinv
            print('Net Profit= {value:.2f}'.format(value=totalgain))
            
            gain_percentage = totalgain/totalinv*100
            print('percentage Gained = {value:.2f}'.format(value=gain_percentage))
            
            
            ##for 3yr
            print("\nRETURNS FOR 3YEAR \n")
            
            totalinv = amount * 36
            print('Total Amount Invested = {value:.2f}'.format(value=totalinv))
            
            Year3 = equity3 + equity23
            print('Total Portfolio Value = {value:.2f}'.format(value=Year3))
            
            
            totalgain = Year3 - totalinv
            print('Net Profit= {value:.2f}'.format(value=totalgain))
            
            gain_percentage = totalgain/totalinv*100
            print('percentage Gained = {value:.2f}'.format(value=gain_percentage))
            
            
            ##for 5yr 
            print("\nRETURNS FOR 5YEAR \n")
            totalinv = amount * 60
            print('Total Amount Invested = {value:.2f}'.format(value=totalinv))
            
            Year5 = equity5 + equity25
            print('Total Portfolio Value = {value:.2f}'.format(value=Year5))
            
            
            totalgain = Year5 - totalinv
            print('Net Profit= {value:.2f}'.format(value=totalgain))
            
            gain_percentage = totalgain/totalinv*100
            print('percentage Gained = {value:.2f}'.format(value=gain_percentage))
            
        else:
            a = 100 - age
            b = a/100
            equity = amount * b
            hybrid = amount - equity
            hybrid = a/2
            debt = a/2
            
            #FOR EQUITY Funds 
            fund1 = equity/2
            fund2 = equity/2
            
            
            #FOR EQUITY fund 1
            a = df.loc[row[0]]
            rate = a.Return_1Yr
            equity1 = calculator(fund1,rate,1)
            
            rate = a.Return_3Yr
            equity3 = calculator(fund1,rate,3)
            
            rate = a.Return_5Yr
            equity5 = calculator(fund1,rate,5)
            
            #FOR EQUITY fund 2
            a = df.loc[row[1]]
            rate = a.Return_1Yr
            equity21 = calculator(fund2,rate,1)
            
            rate = a.Return_3Yr
            equity23 = calculator(fund2,rate,3)
            
            rate = a.Return_5Yr
            equity25 = calculator(fund2,rate,5)
            
            
            #FOR HYBRID 
            
            a = df.loc[row[2]]
            rate = a.Return_1Yr
            hybrid1 = calculator(hybrid,rate,1)
            
            rate = a.Return_3Yr
            hybrid3 = calculator(hybrid,rate,3)
            
            rate = a.Return_5Yr
            hybrid5 = calculator(hybrid,rate,5)
            
            
            #FOR DEBT
            
            a = df.loc[row[3]]
            rate = a.Return_1Yr
            debt1 = calculator(debt,rate,1)
            
            rate = a.Return_3Yr
            debt3 = calculator(debt,rate,3)
            
            rate = a.Return_5Yr
            debt5 = calculator(debt,rate,5)
            
            
            #calculating Returns 
            
            ##for 1yr
            print("\nRETURNS FOR 1 YEAR \n")
            
            totalinv = amount * 12
            print('Total Amount Invested = {value:.2f}'.format(value=totalinv))
            
            Year1 = equity1 + equity21 + hybrid1 + debt1
            print('Total Portfolio Value = {value:.2f}'.format(value=Year1))
            
            
            totalgain = Year1 - totalinv
            print('Net Profit= {value:.2f}'.format(value=totalgain))
            
            gain_percentage = totalgain/totalinv*100
            print('percentage Gained = {value:.2f}'.format(value=gain_percentage))
            
            
            ##for 3yr
            print("\nReturns for 3YEAR \n")
            
            totalinv = amount * 36
            print('Total Amount Invested = {value:.2f}'.format(value=totalinv))
            
            Year3 = equity3 + equity23 + hybrid3 + debt3
            print('Total Portfolio Value = {value:.2f}'.format(value=Year3))
            
            
            totalgain = Year3 - totalinv
            print('Net Profit= {value:.2f}'.format(value=totalgain))
            
            gain_percentage = totalgain/totalinv*100
            print('percentage Gained = {value:.2f}'.format(value=gain_percentage))
            
            
            ##for 5yr 
            print("\nRETURNS FOR 5YEAR \n")
            totalinv = amount * 60
            print('Total Amount Invested = {value:.2f}'.format(value=totalinv))
            
            Year5= equity5 + equity25 + hybrid5 + debt5
            print('Total Portfolio Value = {value:.2f}'.format(value=Year5))
            
            
            totalgain = Year5 - totalinv
            print('Net Profit= {value:.2f}'.format(value=totalgain))
            
            gain_percentage = totalgain/totalinv*100
            print('percentage Gained = {value:.2f}'.format(value=gain_percentage))
            
  


    elif amount> 10000:
        if age<= 18:
            amount1 = amount/3
            amount2 = amount/3
            amount3 = amount/3
            
            a = df.loc[row[0]]
            rate = a.Return_1Yr
            equity1 = calculator(amount1, rate, 1)

            rate = a.Return_3Yr
            equity3 = calculator(amount1, rate, 3)

            rate = a.Return_5Yr
            equity5 = calculator(amount1, rate, 5)
            
            b = df.loc[row[1]]
            rate = b.Return_1Yr
            equity21 = calculator(amount2, rate, 1)
            
            rate = b.Return_3Yr
            equity23 = calculator(amount2, rate, 3)

            rate = b.Return_5Yr
            equity25 = calculator(amount2, rate, 5)

            c = df.loc[row[2]]
            rate = c.Return_1Yr
            equity31 = calculator(amount3, rate, 1)
            
            rate = c.Return_3Yr
            equity33 = calculator(amount3, rate, 3)

            rate = c.Return_5Yr
            equity35 = calculator(amount3, rate, 5)
            
            #calculating returns
            
            ##for 1yr
            print("\n RETURNS FOR 1 YEAR \n")
            
            totalinv = amount * 12
            print('Total Amount Invested = {value:.2f}'.format(value=totalinv))
            
            Year1 = equity1 + equity21 + equity31
            print('Total Portfolio Value = {value:.2f}'.format(value=Year1))
            
            
            totalgain = Year1 - totalinv
            print('Net Profit= {value:.2f}'.format(value=totalgain))
            
            gain_percentage = totalgain/totalinv*100
            print('percentage Gained = {value:.2f}'.format(value=gain_percentage))
            
            
            ##for 3yr
            print("\nRETURNS FOR 3YEAR \n")
            
            totalinv = amount * 36
            print('Total Amount Invested = {value:.2f}'.format(value=totalinv))
            
            Year3 = equity3 + equity23 + equity33
            print('Total Portfolio Value = {value:.2f}'.format(value=Year3))
            
            
            totalgain = Year3 - totalinv
            print('Net Profit= {value:.2f}'.format(value=totalgain))
            
            gain_percentage = totalgain/totalinv*100
            print('percentage Gained = {value:.2f}'.format(value=gain_percentage))
            
            
            ##for 5yr 
            print("\nRETURNS FOR 5YEAR \n")
            totalinv = amount * 60
            print('Total Amount Invested = {value:.2f}'.format(value=totalinv))
            
            Year5= equity5 + equity25 + equity35
            print('Total Portfolio Value = {value:.2f}'.format(value=Year5))
            
            
            totalgain = Year5 - totalinv
            print('Net Profit= {value:.2f}'.format(value=totalgain))
            
            gain_percentage = totalgain/totalinv*100
            print('percentage Gained = {value:.2f}'.format(value=gain_percentage))
            
        
        else:
            a = 100 - age
            b = a/100
            equity = amount * b
            hybrid = amount - equity
            hybrid = a/2
            debt = a/2
        
            #for equity funds
            fund1 = equity/3
            fund2 = equity/3
            fund3 = equity/3
            
            #FOR EQUITY fund 1
            a = df.loc[row[0]]
            rate = a.Return_1Yr
            equity1 = calculator(fund1,rate,1)
            
            rate = a.Return_3Yr
            equity3 = calculator(fund1,rate,3)
            
            rate = a.Return_5Yr
            equity5 = calculator(fund1,rate,5)
            
            #FOR EQUITY fund 2
            a = df.loc[row[1]]
            rate = a.Return_1Yr
            equity21 = calculator(fund2,rate,1)
            
            rate = a.Return_3Yr
            equity23 = calculator(fund2,rate,3)
            
            rate = a.Return_5Yr
            equity25 = calculator(fund2,rate,5)
            
            #FOR EQUITY fund 3
            a = df.loc[row[2]]
            rate = a.Return_1Yr
            equity31 = calculator(fund3,rate,1)
            
            rate = a.Return_3Yr
            equity33 = calculator(fund3,rate,3)
            
            rate = a.Return_5Yr
            equity35 = calculator(fund3,rate,5)
            
            
            #FOR HYBRID 
            
            a = df.loc[row[3]]
            rate = a.Return_1Yr
            hybrid1 = calculator(hybrid,rate,1)
            
            rate = a.Return_3Yr
            hybrid3 = calculator(hybrid,rate,3)
            
            rate = a.Return_5Yr
            hybrid5 = calculator(hybrid,rate,5)
            
            
            #FOR DEBT
            
            a = df.loc[row[4]]
            rate = a.Return_1Yr
            debt1 = calculator(debt,rate,1)
            
            rate = a.Return_3Yr
            debt3 = calculator(debt,rate,3)
            
            rate = a.Return_5Yr
            debt5 = calculator(debt,rate,5)
            
            
            #calculating Returns 
            
            ##for 1yr
            print("\nRETURNS FOR 1 YEAR \n")
            
            totalinv = amount * 12
            print('Total Amount Invested = {value:.2f}'.format(value=totalinv))
            
            Year1 = equity1 + equity21 + equity31 + hybrid1 + debt1
            print('Total Portfolio Value = {value:.2f}'.format(value=Year1))
            
            
            totalgain = Year1 - totalinv
            print('Net Profit= {value:.2f}'.format(value=totalgain))
            
            gain_percentage = totalgain/totalinv*100
            print('percentage Gained = {value:.2f}'.format(value=gain_percentage))
            
            
            ##for 3yr
            print("\nRETURNS FOR 3YEAR \n")
            
            totalinv = amount * 36
            print('Total Amount Invested = {value:.2f}'.format(value=totalinv))
            
            Year3 = equity3 + equity23 + equity33 + hybrid3 + debt3
            print('Total Portfolio Value = {value:.2f}'.format(value=Year3))
            
            
            totalgain = Year3 - totalinv
            print('Net Profit= {value:.2f}'.format(value=totalgain))
            
            gain_percentage = totalgain/totalinv*100
            print('percentage Gained = {value:.2f}'.format(value=gain_percentage))
            
            
            ##for 5yr 
            print("\nRETURNS FOR 5YEAR \n")
            totalinv = amount * 60
            print('Total Amount Invested = {value:.2f}'.format(value=totalinv))
            
            Year5= float(equity5) + float(equity25) + float(equity35) + float(hybrid5) + float(debt5)
            print('Total Portfolio Value = {value:.2f}'.format(value=Year5))
            
            
            totalgain = Year5 - totalinv
            print('Net Profit= {value:.2f}'.format(value=totalgain))
            
            gain_percentage = totalgain/totalinv*100
            print('percentage Gained = {value:.2f}'.format(value=gain_percentage))

# %% [markdown]
# # Dashboard

# %%
while(True):
    age = input("Please enter age:")
    if age.isnumeric():
        age = int(age)
        if age > 100:
            print('Please enter Appropriate age.\n') 
        elif age <= 18:
            b = 1
            break
            
        else:
            a = 100 - age
            b = a/100
            break
    else:
        print('Please enter appr age:')
    
#a = 100-age
#print('a = ',a)

#b= a/100


#equity = amt * b

#print("equity =",equity)
#temp = amt - equity

#hybrid = temp/2
#debt =temp/2

#print('hybrid =', hybrid)
#print('debt=',debt)

while(True):
    while(True):
        amt = input("Enter the amount you want to invest:")
        if amt.isnumeric():
            amt = int(amt)
            break 
        else: 
            print("Inappropriate amount enter again")

    if amt<1000:  
        print("Amount must be greater than 1000")

    elif amt>=1000 and amt<=5000:
        if age< 18:
            equity = amt * b
            row = []
            print("Equity=",equity)
            row.append(displayrow(df,'Equity'))
            
            xyz = df.loc[row]
            xyz.to_csv("mutual_funds_dashboard.csv")
            
            calculate(df, amt, age, row)
            break
        else:
            equity = amt * b
            hybrid = amt - equity
            row = []
            print("Equity=",equity)
            row.append(displayrow(df,'Equity'))
            print("Hybrid=",hybrid)
            row.append(displayrow(df,'Hybrid'))
            
            xyz = df.loc[row]
            xyz.to_csv("mutual_funds_dashboard.csv")
            
            calculate(df, amt, age, row)
            break

    elif amt>5000 and amt<=10000:
        if age< 18:
            equity = amt * b
            row = []
            print("Equity=",equity)
            
            row.append(displayrow(df,'Equity'))
            
            xyz = df.loc[row]
            xyz.to_csv("mutual_funds_dashboard.csv")
            
            calculate(df,amt,age,row)
            break
        else:
            equity = amt * b
            temp = amt - equity
            hybrid = temp/2
            debt = temp/2
            
            row =[]
            print("equity=",equity)
            
            print("Choose first option")
            row.append(displayrow2(df,'Equity',5)) 
            
            print("Choose second option")
            row.append(displayrow2(df,'Equity',4)) 
            
            print("Hybrid=",hybrid)
            row.append(displayrow(df,'Hybrid'))
            
            print("Debt=",debt)
            row.append(displayrow(df,'Debt'))
            
            
            xyz = df.loc[row]
            xyz.to_csv("mutual_funds_dashboard.csv")
            
            calculate(df,amt,age,row)
            
            break
            
            

    elif amt>10000:
        if age< 18:
            equity = amt * b
            row= []
            print("Equity=",equity)
            row.append(displayrow2(df,'Equity', 5))
            row.append(displayrow2(df,'Equity', 5))
            row.append(displayrow2(df,'Equity', 5))
            
            xyz = df.loc[row]
            xyz.to_csv("mutual_funds_dashboard.csv")
            
            calculate(df,amt,age,row)
       
            break

        else:
            
            equity = amt * b
            temp = amt - equity
            hybrid = temp/2
            debt = temp/2
            
            row = []
            print("equity=",equity)
            print("Choose your first option")
            row.append(displayrow2(df,'Equity',5)) 
            print("Choose your second option")
            row.append(displayrow2(df,'Equity',4)) 
            print("Choose your third option")
            row.append(displayrow2(df,'Equity',3)) 
            print("Hybrid=",hybrid)
            row.append(displayrow(df,'Hybrid'))
            print("Debt=",debt)
            row.append(displayrow(df,'Debt'))
            
            xyz = df.loc[row]
            xyz.to_csv("mutual_funds_dashboard.csv")
            
            calculate(df,amt,age,row)
            break

    else: 
        print(" invalidation")
# Out:
# Please enter age:20
# Enter the amount you want to invest:12000
# equity= 9600.0
# Choose your first option
#     AmcName                                Mutual_Fund_Name  \
# 103   Quant        Quant Infrastructure Fund Direct Growth
# 36    Parag       Parag Parikh Tax Saver Fund Direct Growth
# 55     PGIM  PGIM India Midcap Opportunities Fund Direct Gr
#
#                                               Holdings Category  \
# 103  Financial/Energy/Services/Construction/Metal &...   Equity
# 36   Financial/Technology/Automobile/Energy/Consume...   Equity
# 55   Consumer Durables/Industrial Products/Banks/Fi...   Equity
#
#            Risktype  Fundrating  Return_1Yr  Return_3Yr  Return_5Yr  \
# 103  Very High Risk         5.0       16.60      42.800      21.000
# 36    Moderate Risk         5.0        0.82       0.164       0.265
# 55   Very High Risk         5.0        5.30      32.200      18.200
#
#      Expense_Ratio
# 103           0.64
# 36            0.23
# 55            0.46
# Press y to choose specific AMC
# Press n to continue
# Please Enter your choice: n
# Enter your choice103
# Choice =  103
# AmcName                                                         Quant
# Mutual_Fund_Name             Quant Infrastructure Fund Direct Growth
# Holdings            Financial/Energy/Services/Construction/Metal &...
# Category                                                       Equity
# Risktype                                               Very High Risk
# Fundrating                                                        5.0
# Return_1Yr                                                       16.6
# Return_3Yr                                                       42.8
# Return_5Yr                                                       21.0
# Expense_Ratio                                                    0.64
# Name: 103, dtype: object
# Choose your second option
#       AmcName                                Mutual_Fund_Name  \
# 74    INVESCO        Invesco India Mid Cap Fund Direct Growth
# 23  PRINCIPAL  Principal emerging bluechip fund direct growth
# 64      Union       Union Long Term Equity Fund Direct Growth
#
#                                              Holdings Category  \
# 74  Consumer/discretionary/Industrials/Financials/...   Equity
# 23  Financial/Engineering/Automobile/Technology/Ot...   Equity
# 64  Banks /Petroleum Products/Finance/Auto Compona...   Equity
#
#           Risktype  Fundrating  Return_1Yr  Return_3Yr  Return_5Yr  \
# 74  Very High Risk         4.0       10.13       22.01       15.27
# 23  Very High Risk         4.0       40.44       23.33       20.53
# 64  Very High Risk         4.0       12.90       20.79       13.45
#
#     Expense_Ratio
# 74           0.72
# 23           0.92
# 64           1.62
# Press y to choose specific AMC
# Press n to continue
# Please Enter your choice: y
# ['Canara' 'Axis' 'Shriram' 'Navi' 'LIC' 'TAURUS' 'PRINCIPAL' 'IIFL' 'JM'
#  'Franklin' 'Parag' 'ICICI' 'Baroda' 'PGIM' 'Sundaram' 'Union'
#  'Indiabulls' 'Templeton' 'KOTAK' 'HSBC' 'INVESCO' 'DSP' 'Motilal'
#  'Principal' 'BOI' 'Mirae' 'IDFC' 'Quant' 'Tata' 'HDFC' 'UTI' 'Edelweiss'
#  'Aditya' 'Mahindra' 'BNP' 'IDBI' 'Nippon' 'SBI' 'Bank' 'L&T']
# Enter the Amc you want: HSBC
# userchoice =  HSBC
#    AmcName                          Mutual_Fund_Name  \
# 73    HSBC  HSBC Large Cap Equity Fund Direct Growth
#
#                                              Holdings Category  \
# 73  Financials/Information Technology/Consumer Sta...   Equity
#
#           Risktype  Fundrating  Return_1Yr  Return_3Yr  Return_5Yr  \
# 73  Very High Risk         4.0        8.57       17.63        11.1
#
#     Expense_Ratio
# 73           1.26
# Enter your choice73
# Choice =  73
# AmcName                                                          HSBC
# Mutual_Fund_Name             HSBC Large Cap Equity Fund Direct Growth
# Holdings            Financials/Information Technology/Consumer Sta...
# Category                                                       Equity
# Risktype                                               Very High Risk
# Fundrating                                                        4.0
# Return_1Yr                                                       8.57
# Return_3Yr                                                      17.63
# Return_5Yr                                                       11.1
# Expense_Ratio                                                    1.26
# Name: 73, dtype: object
# Choose your third option
#     AmcName                              Mutual_Fund_Name  \
# 107    HDFC             HDFC Small Cap Fund Direct Growth
# 21   TAURUS  Taurus Discovery (Midcap) fund direct growth
# 17      LIC     LIC MF Large & mid cap fund direct growth
#
#                                               Holdings Category  \
# 107  Services/Others/Financial/Capital Goods/Chemic...   Equity
# 21   Financial/Others/Chemicals/Healthcare/Services...   Equity
# 17   Financial/Others/Chemicals/Services/Technology...   Equity
#
#            Risktype  Fundrating  Return_1Yr  Return_3Yr  Return_5Yr  \
# 107  Very High Risk         3.0       20.30       32.20       13.90
# 21   Very High Risk         3.0       10.90       18.51       11.07
# 17   Very High Risk         3.0        1.77       14.62       10.91
#
#      Expense_Ratio
# 107           0.82
# 21            2.19
# 17            0.84
# Press y to choose specific AMC
# Press n to continue
# Please Enter your choice: n
# Enter your choice107
# Choice =  107
# AmcName                                                          HDFC
# Mutual_Fund_Name                    HDFC Small Cap Fund Direct Growth
# Holdings            Services/Others/Financial/Capital Goods/Chemic...
# Category                                                       Equity
# Risktype                                               Very High Risk
# Fundrating                                                        3.0
# Return_1Yr                                                       20.3
# Return_3Yr                                                       32.2
# Return_5Yr                                                       13.9
# Expense_Ratio                                                    0.82
# Name: 107, dtype: object
# Hybrid= 1200.0
#        AmcName                                 Mutual_Fund_Name  \
# 131  Edelweiss  Edelweiss Balanced Advantage Fund Direct Growth
# 63    Sundaram        Sundaram Equity Hybrid Fund Direct Growth
# 7         Axis             Axis Equity Saver Fund Direct Growth
#
#                                               Holdings Category  \
# 131  Financial/Others/Energy/Technology/Consumer St...   Hybrid
# 63               Banks/Debt/Finance/Automobiles/Others   Hybrid
# 7    Financial/Technology/Automobile/Energy/Constru...   Hybrid
#
#                Risktype  Fundrating  Return_1Yr  Return_3Yr  Return_5Yr  \
# 131      Very High Risk         4.0        6.90        16.4       12.10
# 63   Moderate High Risk         4.0        7.30        14.1       10.10
# 7         Moderate Risk         3.0        5.69         9.6        9.04
#
#      Expense_Ratio
# 131           0.51
# 63            0.54
# 7             0.88
# Press y to choose specific AMC
# Press n to continue
# Please Enter your choice: n
# Enter your choice7
# Choice =  7
# AmcName                                                          Axis
# Mutual_Fund_Name                 Axis Equity Saver Fund Direct Growth
# Holdings            Financial/Technology/Automobile/Energy/Constru...
# Category                                                       Hybrid
# Risktype                                                Moderate Risk
# Fundrating                                                        3.0
# Return_1Yr                                                       5.69
# Return_3Yr                                                        9.6
# Return_5Yr                                                       9.04
# Expense_Ratio                                                    0.88
# Name: 7, dtype: object
# Debt= 1200.0
#     AmcName                              Mutual_Fund_Name  \
# 144    IDBI      IDBI Ultra Short Term Fund Direct Growth
# 96     IDFC         Banking & PSU Debt Fund Direct Growth
# 147  Nippon  Nippon India Money Market Fund Direct Growth
#
#                               Holdings Category              Risktype  \
# 144     Financial/Capital Goods/Others     Debt  Low to Moderate Risk
# 96   FINANACIAL/ENERGY/OTHERS/SOVERGIN     Debt  Low to Moderate Risk
# 147                  Financial /others     Debt         Moderate Risk
#
#      Fundrating  Return_1Yr  Return_3Yr  Return_5Yr  Expense_Ratio
# 144         3.0        5.27        4.87         5.9           0.25
# 96          5.0        2.22        6.63        16.6           0.32
# 147         5.0        5.60        5.00         6.2           0.21
# Press y to choose specific AMC
# Press n to continue
# Please Enter your choice: n
# Enter your choice147
# Choice =  147
# AmcName                                                   Nippon
# Mutual_Fund_Name    Nippon India Money Market Fund Direct Growth
# Holdings                                       Financial /others
# Category                                                    Debt
# Risktype                                           Moderate Risk
# Fundrating                                                   5.0
# Return_1Yr                                                   5.6
# Return_3Yr                                                   5.0
# Return_5Yr                                                   6.2
# Expense_Ratio                                               0.21
# Name: 147, dtype: object
# Following are the funds you have chosen:
#     AmcName                              Mutual_Fund_Name  \
# 103   Quant      Quant Infrastructure Fund Direct Growth
# 73     HSBC      HSBC Large Cap Equity Fund Direct Growth
# 107    HDFC             HDFC Small Cap Fund Direct Growth
# 7      Axis          Axis Equity Saver Fund Direct Growth
# 147  Nippon  Nippon India Money Market Fund Direct Growth
#
#                                               Holdings Category  \
# 103  Financial/Energy/Services/Construction/Metal &...   Equity
# 73   Financials/Information Technology/Consumer Sta...   Equity
# 107  Services/Others/Financial/Capital Goods/Chemic...   Equity
# 7    Financial/Technology/Automobile/Energy/Constru...   Hybrid
# 147                                  Financial /others     Debt
#
#            Risktype  Fundrating  Return_1Yr  Return_3Yr  Return_5Yr  \
# 103  Very High Risk         5.0       16.60       42.80       21.00
# 73   Very High Risk         4.0        8.57       17.63       11.10
# 107  Very High Risk         3.0       20.30       32.20       13.90
# 7     Moderate Risk         3.0        5.69        9.60        9.04
# 147   Moderate Risk         5.0        5.60        5.00        6.20
#
#      Expense_Ratio
# 103           0.64
# 73            1.26
# 107           0.82
# 7             0.88
# 147           0.21
# RETURNS FOR 1 YEAR
#
# Total Amount Invested = 144000.00
# Total Portfolio Value = 124427.59
# Net Profit= -19572.41
# percentage Gained = -13.59
#
# Returns for 3YEAR
#
# Total Amount Invested = 432000.00
# Total Portfolio Value = 585836.58
# Net Profit= 153836.58
# percentage Gained = 35.61
#
# RETURNS FOR 5YEAR
#
# Total Amount Invested = 720000.00
# Total Portfolio Value = 903999.04
# Net Profit= 183999.04
# percentage Gained = 25.56

# %%
a = 'Equity'
userchoice = 'SBI'

dt = df.loc[(df["AmcName"] ==  userchoice) & (df["Category"] ==  a)]

# %%
dt

# %%
df.head()

# %%
a=df.AmcName.tolist()
print(a)

# %%
df.AmcName.unique()

# %%
#userchoice

userchoice = input("Enter the Amc you want")
if userchoice == 'y':
    (displayrow(df,'Equity')
else:
